# %% [markdown]
# # 数据集预处理
# 针对单个数据集进行严格的：
# - 设置随机种子
# - 样本筛选
# - 细胞质控
# - 去除环境污染（是否需要？）
# - 保存质控后数据至'UC/scRNA-seq_data/03_qc_filtered'文件夹
# - 批次效应查看
# - 降维聚类结果
# - 处理异常细胞群
# - 区分主要谱系

# %% [markdown]
# # 文件说明
# - **文件名**: 7_GSE231993_qc.h5ad
# - **存放位置**: 坚果云  `UC/scRNA-seq_data/03_qc_filtered/`
# - **生成日期**: 2025-11-3
# - **生成者**: Jiang Lai
# - **对应脚本**: notebooks/1_preprocessing/1.2_qc_filtered/7_GSE231993.ipynb
# - **内容说明**: 完成了针对单个数据的预处理工作，包括样本排除、细胞质控，并查看了样本间的批次效应。

# %%
import numpy as np
import random
np.random.seed(42)
random.seed(42)

# %%
import scanpy as sc
sc.settings.verbosity = 1
print(sc.__version__)
# Out:
# 1.9.6
# /Users/future/miniconda3/envs/scanpy/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /Users/future/miniconda3/envs/scanpy/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /Users/future/miniconda3/envs/scanpy/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /Users/future/miniconda3/envs/scanpy/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /Users/future/miniconda3/envs/scanpy/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /Users/future/miniconda3/envs/scanpy/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /Users/future/miniconda3/envs/scanpy/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /Users/future/miniconda3/envs/scanpy/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /Users/future/miniconda3/envs/scanpy/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /Users/future/miniconda3/envs/scanpy/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /Users/future/miniconda3/envs/scanpy/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /Users/future/miniconda3/envs/scanpy/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /Users/future/miniconda3/envs/scanpy/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## 读取数据
# GSE231993数据集：
# - 结肠组织
# - 4UC，8HC

# %%
adata = sc.read_h5ad('/Users/future/Nutstore Files/UC/scRNA-seq_data/02_sample_merge/7_GSE231993.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 44266 × 14314
#     obs: 'n_genes', 'GSM_id', 'GSM', 'id', 'nUMIs', 'mito_perc', 'detected_genes', 'cell_complexity', 'passing_mt', 'passing_nUMIs', 'passing_ngenes', 'doublet_score', 'predicted_doublet'
#     var: 'gene_ids', 'feature_types', 'mt', 'n_cells'
#     uns: 'REFERENCE_MANU', 'scrublet', 'status', 'status_args'

# %%
adata.obs.head()
# Out:
#                                     n_genes           GSM_id         GSM  \
# GSM7307094_HC39_AAACCTGAGAACAATC-1     1370  GSM7307094_HC39  GSM7307094
# GSM7307094_HC39_AAACCTGAGGTAGCCA-1      780  GSM7307094_HC39  GSM7307094
# GSM7307094_HC39_AAACCTGAGTAGGCCA-1     1071  GSM7307094_HC39  GSM7307094
# GSM7307094_HC39_AAACCTGCATCCTAGA-1     2806  GSM7307094_HC39  GSM7307094
# GSM7307094_HC39_AAACCTGGTTACGGAG-1     1855  GSM7307094_HC39  GSM7307094
#
#                                       id    nUMIs  mito_perc  detected_genes  \
# GSM7307094_HC39_AAACCTGAGAACAATC-1  HC39   3987.0   0.032606            1370
# GSM7307094_HC39_AAACCTGAGGTAGCCA-1  HC39   1979.0   0.175846             780
# GSM7307094_HC39_AAACCTGAGTAGGCCA-1  HC39   3280.0   0.035061            1071
# GSM7307094_HC39_AAACCTGCATCCTAGA-1  HC39  10609.0   0.051089            2806
# GSM7307094_HC39_AAACCTGGTTACGGAG-1  HC39  31156.0   0.014636            1855
#
#                                     cell_complexity  passing_mt  \
# GSM7307094_HC39_AAACCTGAGAACAATC-1         0.343617        True
# GSM7307094_HC39_AAACCTGAGGTAGCCA-1         0.394138        True
# GSM7307094_HC39_AAACCTGAGTAGGCCA-1         0.326524        True
# GSM7307094_HC39_AAACCTGCATCCTAGA-1         0.264492        True
# GSM7307094_HC39_AAACCTGGTTACGGAG-1         0.059539        True
#
#                                     passing_nUMIs  passing_ngenes  \
# GSM7307094_HC39_AAACCTGAGAACAATC-1           True            True
# GSM7307094_HC39_AAACCTGAGGTAGCCA-1           True            True
# GSM7307094_HC39_AAACCTGAGTAGGCCA-1           True            True
# GSM7307094_HC39_AAACCTGCATCCTAGA-1           True            True
# GSM7307094_HC39_AAACCTGGTTACGGAG-1           True            True
#
#                                     doublet_score  predicted_doublet
# GSM7307094_HC39_AAACCTGAGAACAATC-1       0.019885              False
# GSM7307094_HC39_AAACCTGAGGTAGCCA-1       0.073457              False
# GSM7307094_HC39_AAACCTGAGTAGGCCA-1       0.036474              False
# GSM7307094_HC39_AAACCTGCATCCTAGA-1       0.070128              False
# GSM7307094_HC39_AAACCTGGTTACGGAG-1       0.029534              False

# %% [markdown]
# ## 处理细胞标签及分组

# %%
# 提取分组信息
import pandas as pd
adata.obs['group'] = adata.obs['id'].str.extract(r'([A-Za-z]+)', expand=False)
print(adata.obs[['id', 'group']].head())
# Out:
#                                       id group
# GSM7307094_HC39_AAACCTGAGAACAATC-1  HC39    HC
# GSM7307094_HC39_AAACCTGAGGTAGCCA-1  HC39    HC
# GSM7307094_HC39_AAACCTGAGTAGGCCA-1  HC39    HC
# GSM7307094_HC39_AAACCTGCATCCTAGA-1  HC39    HC
# GSM7307094_HC39_AAACCTGGTTACGGAG-1  HC39    HC

# %% [markdown]
# `.obs`当中只保留GSM信息和分组信息

# %%
adata.obs.drop(columns=['GSM_id', 'id'], inplace=True)
print(adata.obs.head())
# Out:
#                                     n_genes         GSM    nUMIs  mito_perc  \
# GSM7307094_HC39_AAACCTGAGAACAATC-1     1370  GSM7307094   3987.0   0.032606
# GSM7307094_HC39_AAACCTGAGGTAGCCA-1      780  GSM7307094   1979.0   0.175846
# GSM7307094_HC39_AAACCTGAGTAGGCCA-1     1071  GSM7307094   3280.0   0.035061
# GSM7307094_HC39_AAACCTGCATCCTAGA-1     2806  GSM7307094  10609.0   0.051089
# GSM7307094_HC39_AAACCTGGTTACGGAG-1     1855  GSM7307094  31156.0   0.014636
#
#                                     detected_genes  cell_complexity  \
# GSM7307094_HC39_AAACCTGAGAACAATC-1            1370         0.343617
# GSM7307094_HC39_AAACCTGAGGTAGCCA-1             780         0.394138
# GSM7307094_HC39_AAACCTGAGTAGGCCA-1            1071         0.326524
# GSM7307094_HC39_AAACCTGCATCCTAGA-1            2806         0.264492
# GSM7307094_HC39_AAACCTGGTTACGGAG-1            1855         0.059539
#
#                                     passing_mt  passing_nUMIs  passing_ngenes  \
# GSM7307094_HC39_AAACCTGAGAACAATC-1        True           True            True
# GSM7307094_HC39_AAACCTGAGGTAGCCA-1        True           True            True
# GSM7307094_HC39_AAACCTGAGTAGGCCA-1        True           True            True
# GSM7307094_HC39_AAACCTGCATCCTAGA-1        True           True            True
# GSM7307094_HC39_AAACCTGGTTACGGAG-1        True           True            True
#
#                                     doublet_score  predicted_doublet group
# GSM7307094_HC39_AAACCTGAGAACAATC-1       0.019885              False    HC
# GSM7307094_HC39_AAACCTGAGGTAGCCA-1       0.073457              False    HC
# GSM7307094_HC39_AAACCTGAGTAGGCCA-1       0.036474              False    HC
# GSM7307094_HC39_AAACCTGCATCCTAGA-1       0.070128              False    HC
# GSM7307094_HC39_AAACCTGGTTACGGAG-1       0.029534              False    HC

# %%
adata.obs['group'].value_counts()
# Out:
# group
# HC    30100
# UC    14166
# Name: count, dtype: int64

# %% [markdown]
# ## 样本质量查看

# %%
adata.obs['GSM'].value_counts()
# Out:
# GSM
# GSM7307099    5766
# GSM7307095    4786
# GSM7307097    4640
# GSM7307105    4414
# GSM7307101    4353
# GSM7307104    4274
# GSM7307102    4037
# GSM7307100    3413
# GSM7307103    3151
# GSM7307094    2665
# GSM7307096    2133
# GSM7307098     634
# Name: count, dtype: int64

# %%
sample_quality_stats = adata.obs.groupby('GSM')[['n_genes', 'nUMIs', 'mito_perc']].agg(['mean', 'std', 'min', 'max'])

print(sample_quality_stats)
# Out:
#                 n_genes                                nUMIs               \
#                    mean          std  min   max         mean          std
# GSM
# GSM7307094  1100.913696  1015.183867  251  6632  4917.028320  8256.656250
# GSM7307095   946.059758   791.025726  251  8380  3954.475098  6432.279297
# GSM7307096  1118.265354   835.490175  251  7148  5357.868652  6971.551758
# GSM7307097  1103.140948   779.277701  251  7158  5681.405273  7326.019043
# GSM7307098  1038.741325  1106.658767  256  8412  4582.716309  9973.733398
# GSM7307099   896.196323   650.067749  251  7055  3919.153564  5805.406250
# GSM7307100  1212.221799   927.488106  251  7650  8077.412598  8871.984375
# GSM7307101  1152.302320   742.386771  251  8870  6596.270508  8101.309570
# GSM7307102   680.504583   388.847665  251  5679  2958.298096  3497.020996
# GSM7307103   867.180260   560.418455  251  6213  5261.937988  6317.035156
# GSM7307104  1030.010763   815.736015  251  7507  5456.315430  7675.897949
# GSM7307105  1244.439964   847.018745  251  7382  7818.272949  9522.056641
#
#                             mito_perc
#               min       max      mean       std       min       max
# GSM
# GSM7307094  501.0   80651.0  0.072878  0.050195  0.000000  0.199927
# GSM7307095  501.0  101306.0  0.053222  0.042959  0.000905  0.199773
# GSM7307096  501.0   62848.0  0.063996  0.046358  0.001089  0.199005
# GSM7307097  501.0   70954.0  0.045130  0.041882  0.000000  0.199681
# GSM7307098  501.0  144047.0  0.039799  0.033990  0.001022  0.196059
# GSM7307099  501.0   76491.0  0.032113  0.029279  0.000000  0.199928
# GSM7307100  501.0   77624.0  0.039416  0.040280  0.000000  0.199681
# GSM7307101  502.0  130809.0  0.032230  0.034875  0.000000  0.199878
# GSM7307102  501.0   43179.0  0.048665  0.032934  0.000700  0.199930
# GSM7307103  505.0   50761.0  0.059531  0.043454  0.000000  0.199313
# GSM7307104  501.0   75590.0  0.055239  0.048242  0.000748  0.199953
# GSM7307105  501.0   74148.0  0.050197  0.045184  0.000000  0.199820
# /var/folders/n6/ygb1nb55663b38zz1rbjx5lm0000gn/T/ipykernel_42574/2761774101.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sample_quality_stats = adata.obs.groupby('GSM')[['n_genes', 'nUMIs', 'mito_perc']].agg(['mean', 'std', 'min', 'max'])

# %% [markdown]
# ## 细胞质控

# %%
import matplotlib.pyplot as plt

# 选择要可视化的质量控制指标
qc_metrics = ['n_genes', 'nUMIs', 'mito_perc']

# 绘制各个指标的直方图
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

# 绘制每个质量控制指标的直方图
for i, metric in enumerate(qc_metrics):
    ax[i].hist(adata.obs[metric], bins=50, color='skyblue', edgecolor='black')
    ax[i].set_title(f'Distribution of {metric}')
    ax[i].set_xlabel(metric)
    ax[i].set_ylabel('Cell Count')

# 调整布局，避免重叠
plt.tight_layout()
plt.show()

# %%
# 设置绘图风格
sc.settings.verbosity = 0  # 简化日志输出

# 选择要绘制的小提琴图的质量控制指标
qc_metrics = ['n_genes', 'nUMIs', 'mito_perc']

# 按照样本（GSM）绘制小提琴图
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

for i, metric in enumerate(qc_metrics):
    sc.pl.violin(adata, keys=metric, groupby='GSM', ax=ax[i], stripplot=True, jitter=0.4, show=False)
    ax[i].set_title(f'{metric} by GSM')
    ax[i].set_ylabel(f'{metric}')
    
    # 获取当前的x轴标签
    labels = ax[i].get_xticklabels()
    # 旋转标签并调整对齐方式（末尾对齐）
    ax[i].set_xticklabels(labels, rotation=45, ha='right')

# 调整布局，避免重叠
plt.tight_layout()
plt.show()
# Out:
# /Users/future/miniconda3/envs/scanpy/lib/python3.10/site-packages/scanpy/plotting/_anndata.py:840: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.violinplot(
# /Users/future/miniconda3/envs/scanpy/lib/python3.10/site-packages/scanpy/plotting/_anndata.py:840: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(
# /var/folders/n6/ygb1nb55663b38zz1rbjx5lm0000gn/T/ipykernel_42574/2077234365.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(labels, rotation=45, ha='right')
# /Users/future/miniconda3/envs/scanpy/lib/python3.10/site-packages/scanpy/plotting/_anndata.py:840: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.violinplot(
# /Users/future/miniconda3/envs/scanpy/lib/python3.10/site-packages/scanpy/plotting/_anndata.py:840: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(
# /var/folders/n6/ygb1nb55663b38zz1rbjx5lm0000gn/T/ipykernel_42574/2077234365.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(labels, rotation=45, ha='right')
# /Users/future/miniconda3/envs/scanpy/lib/python3.10/site-packages/scanpy/plotting/_anndata.py:840: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.violinplot(
# /Users/future/miniconda3/envs/scanpy/lib/python3.10/site-packages/scanpy/plotting/_anndata.py:840: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(
# /var/folders/n6/ygb1nb55663b38zz1rbjx5lm0000gn/T/ipykernel_42574/2077234365.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(labels, rotation=45, ha='right')

# %% [markdown]
# ### 严格细胞质控标准
# - min_genes = 200          # 最少基因数
# - max_genes = 4000         # 最多基因数
# - min_umis = 500           # 最少UMI数量
# - max_umis = 20000         # 最多UMI数量
# - max_mito_perc = 10       # 线粒体基因百分比最大值

# %%
# 设置阈值
min_genes = 200          # 最少基因数
max_genes = 6000         # 最多基因数
min_umis = 500           # 最少UMI数量
max_umis = 20000        # 最多UMI数量
max_mito_perc = 0.1       # 线粒体基因百分比最大值

# 根据阈值进行过滤
adata = adata[(adata.obs['n_genes'] > min_genes) & 
              (adata.obs['n_genes'] < max_genes) &
              (adata.obs['nUMIs'] > min_umis) &
              (adata.obs['nUMIs'] < max_umis) &
              (adata.obs['mito_perc'] < max_mito_perc), :]

# 输出过滤后的细胞数
print(f'Number of cells after filtering: {adata.n_obs}')
# Out:
# Number of cells after filtering: 36404

# %% [markdown]
# ## 保存质控后数据

# %%
import os
output_dir = "/Users/future/Nutstore Files/UC/scRNA-seq_data/03_qc_filtered/"
os.makedirs(output_dir, exist_ok=True)
adata.write_h5ad(os.path.join(output_dir, "7_GSE231993_qc.h5ad"), compression='gzip')

# %% [markdown]
# ## 降维聚类

# %%
import omicverse as ov
ov.plot_set(dpi=50)
ov.settings.verbose = 1 
ov.settings.cpu_gpu_mixed_init()

# %% [markdown]
# 血液组织细胞，所以选取2000个高变基因
# 大致分别谱系，所以选取resolution=0.4

# %%
# HVG
adata=ov.pp.preprocess(adata,
                       mode='shiftlog|pearson',
                       n_HVGs=2000,
                       target_sum=50*1e4)

adata.raw = adata
adata = adata[:, adata.var.highly_variable_features]

# PCA
ov.pp.scale(adata)
ov.pp.pca(adata,layer='scaled',n_pcs=50)

# Embedding the neighborhood graph
ov.pp.neighbors(adata, 
                n_neighbors=15, 
                n_pcs=50,
                use_rep='scaled|original|X_pca')

# UMAP
ov.pp.umap(adata)

# Clustering
ov.pp.leiden(adata,resolution=0.4)

# %%
# 可视化查看聚类和样本分布
ov.pl.embedding(adata,
                basis='X_umap',
                color=['leiden', 'GSM', 'group'],
                frameon='small',
                wspace=0.5)

# %%
# 免疫谱系
ov.pl.embedding(adata,
                basis='X_umap',
                color=['PTPRC', 'CD3D', 'CD19', 'CD68'], 
                frameon='small')

# %% [markdown]
# ## 去除批次效应
# 按样本去除批次，看看是否效果会更好
#
# 使用`harmony`

# %%
ov.single.batch_correction(adata,
                           batch_key='GSM', # 去批次分组标签
                           methods='harmony',
                           n_pcs=50)
                           
ov.pp.neighbors(adata, 
                n_neighbors=15, 
                n_pcs=50,
                use_rep='X_harmony')

ov.pp.umap(adata)

ov.pp.leiden(adata,resolution=0.4)

# %%
# 可视化查看去除批次效应后聚类和样本分布
ov.pl.embedding(adata,
                basis='X_umap',
                color=['leiden', 'GSM', 'group'],
                frameon='small',
                wspace=0.5)

# %%
# 免疫谱系
ov.pl.embedding(adata,
                basis='X_umap',
                color=['PTPRC', 'CD3D', 'CD19', 'CD68'], 
                frameon='small')

# %% [markdown]
# ## GPT自动注释

# %%
# 获取每个细胞群的基因
all_markers = ov.single.get_celltype_marker(adata,
                                            clustertype='leiden',
                                            rank=True,
                                            key='rank_genes_groups',
                                            foldchange=1,
                                            topgenenumber=10)
all_markers

# %%
os.environ['AGI_API_KEY'] = 'sk-ff0dc715f640466393e6aa71c9da6848'
result = ov.single.gptcelltype(all_markers,
                               tissuename='colon',
                               speciename='human',
                               model='qwen-plus',
                               provider='qwen',
                               topgenenumber=10)
result

# %%
# 添加识别结果到obs
adata.obs['gpt_celltype'] = adata.obs['leiden'].map(result).astype('category')

# %%
# 可视化查看结果
ov.pl.embedding(adata,
                basis='X_umap',
                color=['leiden', 'gpt_celltype'],
                # legend_loc='on data',
                frameon='small',
                legend_fontoutline=0.5,
                palette=ov.utils.palette()[10:],
                wspace=0.3)

# %%
# 统计每种细胞类型数量及占比
celltype_counts = adata.obs['gpt_celltype'].value_counts(normalize=True) * 100
print(celltype_counts)
